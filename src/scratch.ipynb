# %%
from main import *

# %%
img = cv2.imread("../test_images/test1.jpg")

# %%
#(array([ 67, 360]), array([105, 398]))
cropped = img[360:398, 67:105]

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
plt.imshow(cropped)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from classifier import *

# %%
dat_dict = pickle.load(open("../models/model.dat", "rb"))

# %%
scaler = dat_dict['scaler']
cls  = dat_dict['cls']

# %%
test_img  = cv2.resize(cropped, (64, 64))

# %%
fv = get_single_hog_features(test_img, True, get_hog_params()).reshape((1,-1))

# %%
fv = scaler.transform(fv)

# %%
cls.predict(fv)
# Out:
# array([ 0.])
